# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv
# Out:
# C:\Users\ryu\Anaconda3\envs\ecsdeep\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = read_csv('traffic_clean_utf.csv', sep=',')
xy = np.array(data, dtype=np.float32)

# 4개의 변인을 입력을 받습니다. = 독립변수
x_data = xy[:, 1:-1] #행은 전, 열은 날짜빼고 처음부터 사상자 리스트 전까지

# 가격 값을 입력 받습니다. = 종속변수
y_data = xy[:, [-1]] #행은 전, 열은 사상자 리스트 데이터만

# %%
# 입력 데이터 변수를 지정한다. 
X = tf.placeholder(tf.float32, shape=[None, 7]) #독립변수
Y = tf.placeholder(tf.float32, shape=[None, 1]) #종속변수

#변수를 초기화 한다.
W = tf.Variable(tf.random_normal([7, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# 회귀분석 가설을 설정합니다. = 회귀분석 식 (8차원 공간 속 초평면으로 된 직선식) 
hypothesis = tf.matmul(X, W) + b

# 비용 함수를 설정합니다. 
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# 최적화 함수를 설정합니다.
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005) #데이터와 직선 사이의 거리를 최소로 만들어주는 식
train = optimizer.minimize(cost)

# 세션을 생성합니다.
sess = tf.Session()

# 글로벌 변수를 초기화합니다.
model = tf.global_variables_initializer()
sess.run(model)

# 학습을 수행합니다.
for step in range(100000):

    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})

    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("사상자: ", hypo_[0])

# 학습된 모델을 저장합니다.
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')
# Out:
# # 0  손실 비용:  3252.3904
# 사상자:  [83.32892]
# # 500  손실 비용:  22.680508
# 사상자:  [8.743263]
# # 1000  손실 비용:  10.713871
# 사상자:  [4.754698]
# # 1500  손실 비용:  9.020495
# 사상자:  [3.2695231]
# # 2000  손실 비용:  8.726918
# 사상자:  [2.7080991]
# # 2500  손실 비용:  8.625229
# 사상자:  [2.4876673]
# # 3000  손실 비용:  8.550927
# 사상자:  [2.3931892]
# # 3500  손실 비용:  8.481683
# 사상자:  [2.3453662]
# # 4000  손실 비용:  8.414423
# 사상자:  [2.3149521]
# # 4500  손실 비용:  8.348647
# 사상자:  [2.2910047]
# # 5000  손실 비용:  8.284231
# 사상자:  [2.269638]
# # 5500  손실 비용:  8.221133
# 사상자:  [2.2494318]
# # 6000  손실 비용:  8.159406
# 사상자:  [2.2296815]
# # 6500  손실 비용:  8.098986
# 사상자:  [2.2103834]
# # 7000  손실 비용:  8.039801
# 사상자:  [2.1912727]
# # 7500  손실 비용:  7.981795
# 사상자:  [2.1724467]
# # 8000  손실 비용:  7.924961
# 사상자:  [2.1538062]
# # 8500  손실 비용:  7.869381
# 사상자:  [2.135458]
# # 9000  손실 비용:  7.8148956
# 사상자:  [2.1172924]
# # 9500  손실 비용:  7.761486
# 사상자:  [2.099359]
# # 10000  손실 비용:  7.709138
# 사상자:  [2.0815854]
# ...
