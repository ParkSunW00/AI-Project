# %%
import tensorflow as tf
import numpy as np

# 플레이스 홀더를 설정합니다.
X = tf.placeholder(tf.float32, shape=[None, 7])
Y = tf.placeholder(tf.float32, shape=[None, 1])


W = tf.Variable(tf.random_normal([7, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")



# 가설을 설정합니다.
hypothesis = tf.matmul(X, W) + b


# 저장된 모델을 불러오는 객체를 선언합니다.

saver = tf.train.Saver()
model = tf.global_variables_initializer()


# 7가지 변수를 입력 받습니다. 기온,강수량,풍속,습도,일조,적설,지면온도

avg_temp = float(input('온  도: '))
avg_rain = float(input('강수량: '))
wind_vel = float(input('풍  속: '))
humidity = float(input('습  도: '))
sunshine = float(input('일조량: '))
snowfall = float(input('적설량: '))
suf_temp = float(input('표면온도: '))


with tf.Session() as sess:
    sess.run(model)


    # 저장된 학습 모델을 파일로부터 불러옵니다.
    save_path = "saved.cpkt"
    saver.restore(sess, save_path)

    # 사용자의 입력 값을 이용해 배열을 만듭니다.
    data = ((avg_temp, avg_rain, wind_vel, humidity, sunshine, snowfall, suf_temp), )
    arr = np.array(data, dtype=np.float32)



    # 예측을 수행한 뒤에 그 결과를 출력합니다.

    x_data = arr[:]
    dict = sess.run(hypothesis, feed_dict={X: x_data})

    print(dict[0])
# Out:
# 온  도: 1
# 강수량: 1
# 풍  속: 1
# 습  도: 1
# 일조량: 1
# 적설량: 1
# 표면온도: 1
# INFO:tensorflow:Restoring parameters from saved.cpkt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# NotFoundError: Key bias_1 not found in checkpoint
# 	 [[{{node save_1/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1275         sess.run(self.saver_def.restore_op_name,
# -> 1276                  {self.saver_def.filename_tensor_name: save_path})
#    1277     except errors.NotFoundError as err:
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#
# NotFoundError: Key bias_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-4adef47f867b>:20) ]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\IPython\core\interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4adef47f867b>", line 20, in <module>
#     saver = tf.train.Saver()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 832, in __init__
#     self.build()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 844, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 881, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 513, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 332, in _AddRestoreOps
#     restore_sequentially)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 580, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1655, in restore_v2
#     name=name)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): Key bias_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-4adef47f867b>:20) ]]
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1285       try:
# -> 1286         names_to_keys = object_graph_key_mapping(save_path)
#    1287       except errors.NotFoundError:
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py in object_graph_key_mapping(checkpoint_path)
#    1590   object_graph_string = reader.get_tensor(
# -> 1591       checkpointable.OBJECT_GRAPH_PROTO_KEY)
#    1592   object_graph_proto = (
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in get_tensor(self, tensor_str)
#     369         return CheckpointReader_GetTensor(self, compat.as_bytes(tensor_str),
# --> 370                                           status)
#     371
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-2-4adef47f867b> in <module>()
#      39     # 저장된 학습 모델을 파일로부터 불러옵니다.
#      40     save_path = "saved.cpkt"
# ---> 41     saver.restore(sess, save_path)
#      42
#      43     # 사용자의 입력 값을 이용해 배열을 만듭니다.
#
# ~\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1290         # a helpful message (b/110263146)
#    1291         raise _wrap_restore_error_with_msg(
# -> 1292             err, "a Variable name or other graph key that is missing")
#    1293
#    1294       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key bias_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-4adef47f867b>:20) ]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\IPython\core\interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\IPython\core\interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4adef47f867b>", line 20, in <module>
#     saver = tf.train.Saver()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 832, in __init__
#     self.build()
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 844, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 881, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 513, in _build_internal
#     restore_sequentially, reshape)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 332, in _AddRestoreOps
#     restore_sequentially)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\training\saver.py", line 580, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1655, in restore_v2
#     name=name)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 788, in _apply_op_helper
#     op_def=op_def)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\Users\ryu\Anaconda3\envs\ai4ynlp\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key bias_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-4adef47f867b>:20) ]]
